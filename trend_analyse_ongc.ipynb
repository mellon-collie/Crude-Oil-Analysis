# %%
import pandas as pd
import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("merge_oil.csv")

dates = [datetime.date(int(i.split('-')[0]),int(i.split('-')[1]),int(i.split('-')[2])) for i in list(df["Date"])]

df["Dates"] = dates

df["Year"] = [int(i.split('-')[0]) for i in df["Date"]]
df["Month"] = [int(i.split('-')[1]) for i in df["Date"]]
df["Day"] = [int(i.split('-')[2]) for i in df["Date"]]


years = list(set([i.year for i in dates]))
years.sort()
#years

yearly_data_oil = dict()

for i in years:
    yearly_data_oil[i] = df[df["Year"]==i]
    yearly_data_oil[i] = yearly_data_oil[i][["ONGC_Close","Year","Month","Day","Dates"]]
    l = list(yearly_data_oil[i]["ONGC_Close"])
    l.reverse()
    yearly_data_oil[i]["ONGC_Close"] = l
    
    l = list(yearly_data_oil[i]["Year"])
    l.reverse()
    yearly_data_oil[i]["Year"] = l
    
    l = list(yearly_data_oil[i]["Month"])
    l.reverse()
    yearly_data_oil[i]["Month"] = l
    
    l = list(yearly_data_oil[i]["Day"])
    l.reverse()
    yearly_data_oil[i]["Day"] = l
    
    l = list(yearly_data_oil[i]["Dates"])
    l.reverse()
    yearly_data_oil[i]["Dates"] = l
    

    
for i in years:
    print(i)
    plt.plot(yearly_data_oil[i]["Dates"],yearly_data_oil[i]["ONGC_Close"])
    plt.xticks(rotation=90)
    plt.show()
    
    
#print(yearly_data_oil[2011].head())

#print(len(list(yearly_data_oil[2012]["Dates"])))

    

#getting week number for a given date
#datetime.date(2010, 6, 16).isocalendar()[1]
# Out:
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018

# %%
half_yearly_data_oil = dict()
years = list(range(2012,2019))
for i in years:
    half_yearly_data_oil[(1,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]<=6]
    half_yearly_data_oil[(2,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]>6]
    
#print(half_yearly_data_oil[(2,2012)].head())    

for i in half_yearly_data_oil.keys():
    print(i)
    plt.plot(half_yearly_data_oil[i]["Dates"],half_yearly_data_oil[i]["ONGC_Close"])
    plt.xticks(rotation=90)
    plt.show()
# Out:
# (1, 2012)
# (2, 2012)
# (1, 2013)
# (2, 2013)
# (1, 2014)
# (2, 2014)
# (1, 2015)
# (2, 2015)
# (1, 2016)
# (2, 2016)
# (1, 2017)
# (2, 2017)
# (1, 2018)
# (2, 2018)

# %%
quarter_yearly_data_oil = dict()

for i in years:
    quarter_yearly_data_oil[(1,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]<=3]
    quarter_yearly_data_oil[(2,i)] = yearly_data_oil[i][(yearly_data_oil[i]["Month"]<=6) & (yearly_data_oil[i]["Month"]>3)]
    quarter_yearly_data_oil[(3,i)] = yearly_data_oil[i][(yearly_data_oil[i]["Month"]<=9) & (yearly_data_oil[i]["Month"]>6)]
    quarter_yearly_data_oil[(4,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]>9]
    
for i in quarter_yearly_data_oil.keys():
    print(i)
    plt.plot(quarter_yearly_data_oil[i]["Dates"],quarter_yearly_data_oil[i]["ONGC_Close"])
    plt.xticks(rotation=90)
    plt.show()
# Out:
# (1, 2012)
# (2, 2012)
# (3, 2012)
# (4, 2012)
# (1, 2013)
# (2, 2013)
# (3, 2013)
# (4, 2013)
# (1, 2014)
# (2, 2014)
# (3, 2014)
# (4, 2014)
# (1, 2015)
# (2, 2015)
# (3, 2015)
# (4, 2015)
# (1, 2016)
# (2, 2016)
# (3, 2016)
# (4, 2016)
# (1, 2017)
# (2, 2017)
# (3, 2017)
# (4, 2017)
# (1, 2018)
# (2, 2018)
# (3, 2018)
# (4, 2018)

# %%
month_yearly_data_oil = dict()
years = list(range(2012,2019))
for i in years:
    month_yearly_data_oil[(1,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==1]
    month_yearly_data_oil[(2,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==2]
    month_yearly_data_oil[(3,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==3]
    month_yearly_data_oil[(4,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==4]
    month_yearly_data_oil[(5,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==5]
    month_yearly_data_oil[(6,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==6]
    month_yearly_data_oil[(7,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==7]
    month_yearly_data_oil[(8,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==8]
    month_yearly_data_oil[(9,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==9]
    month_yearly_data_oil[(10,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==10]
    month_yearly_data_oil[(11,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==11]
    month_yearly_data_oil[(12,i)] = yearly_data_oil[i][yearly_data_oil[i]["Month"]==12]
    
    
#print(half_yearly_data_oil[(2,2012)].head())    

for i in month_yearly_data_oil.keys():
    print(i)
    plt.plot(month_yearly_data_oil[i]["Dates"],month_yearly_data_oil[i]["ONGC_Close"])
    plt.xticks(rotation=90)
    plt.show()
# Out:
# (1, 2012)
# (2, 2012)
# (3, 2012)
# (4, 2012)
# (5, 2012)
# (6, 2012)
# (7, 2012)
# (8, 2012)
# (9, 2012)
# (10, 2012)
# (11, 2012)
# (12, 2012)
# (1, 2013)
# (2, 2013)
# (3, 2013)
# (4, 2013)
# (5, 2013)
# (6, 2013)
# (7, 2013)
# (8, 2013)
# (9, 2013)
# (10, 2013)
# (11, 2013)
# (12, 2013)
# (1, 2014)
# (2, 2014)
# (3, 2014)
# (4, 2014)
# (5, 2014)
# (6, 2014)
# (7, 2014)
# (8, 2014)
# (9, 2014)
# (10, 2014)
# (11, 2014)
# (12, 2014)
# (1, 2015)
# (2, 2015)
# (3, 2015)
# (4, 2015)
# (5, 2015)
# (6, 2015)
# (7, 2015)
# (8, 2015)
# (9, 2015)
# (10, 2015)
# (11, 2015)
# (12, 2015)
# (1, 2016)
# (2, 2016)
# (3, 2016)
# (4, 2016)
# (5, 2016)
# (6, 2016)
# (7, 2016)
# (8, 2016)
# (9, 2016)
# (10, 2016)
# (11, 2016)
# (12, 2016)
# (1, 2017)
# (2, 2017)
# (3, 2017)
# (4, 2017)
# (5, 2017)
# (6, 2017)
# (7, 2017)
# (8, 2017)
# (9, 2017)
# (10, 2017)
# (11, 2017)
# (12, 2017)
# (1, 2018)
# (2, 2018)
# (3, 2018)
# (4, 2018)
# (5, 2018)
# (6, 2018)
# (7, 2018)
# (8, 2018)
# (9, 2018)
# ...
